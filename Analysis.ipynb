# %% [markdown]
# # Diabetes Risk Prediction System - Python, SQL, MlFLow

# %% [markdown]
# ### Step-1: Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from config import CONFIG

from Database.databasemanager import DatabaseManager
from core.datapreprocessor import DataPreprocessor
from core.modelevaluator import ModelEvaluator
from core.mlflowtracker import MLflowTracker
from core.pipeline import DiabetesPredictionPipeline

# %% [markdown]
# ### Step-2: Data Processing, Model Training, Evaluation, MLFlow Tracking

# %%
pipeline = DiabetesPredictionPipeline()
# Out:
# 18:34:05  [INFO]  DiabetesPredictionPipeline initialized

# %%
pipeline = DiabetesPredictionPipeline()
results = pipeline.run_training()
# Out:
# 2026/04/20 15:29:24 INFO mlflow.tracking.fluent: Experiment with name 'Diabetes_Risk_Prediction' does not exist. Creating a new experiment.
# 15:29:24  [INFO]  DiabetesPredictionPipeline initialized
# 15:29:24  [INFO]  Loading data from CSV...
# 15:29:24  [INFO]  Data already exists in MySQL, skipping insert.
# 15:29:24  [INFO]  Preparing data...
# 15:29:24  [INFO]    Features: ['pregnancies', 'glucose', 'blood_pressure', 'skin_thickness', 'insulin', 'bmi', 'diabetes_pedigree', 'age', 'glucose_bmi', 'insulin_glucose_ratio', 'age_risk', 'bmi_category']
# 15:29:24  [INFO]    Shape: (768, 12) | Diabetic: 268 / 768
# 15:29:24  [INFO]    Train: (614, 12) |  Test: (154, 12)
# 15:29:24  [INFO]
# Training: LogisticRegression
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: divide by zero encountered in matmul
#   raw_prediction = X @ weights + intercept
# ...

# %%
patient_data = {
    'Pregnancies': 2,
    'Glucose': 120,
    'BloodPressure': 70,
    'SkinThickness': 20,
    'Insulin': 85,
    'BMI': 28.0,
    'DiabetesPedigreeFunction': 0.5,
    'Age': 30
}
patient_id = 'patient_001'
result = pipeline.predict(patient_data, patient_id)
print(result)
# Out:
# 18:34:10  [INFO]  Preprocessor state loaded from preprocessor.pkl
# 18:34:10  [INFO]  Loaded preprocessor state from disk.
# 18:34:10  [INFO]  Loaded production model from: models:/DiabetesRiskModel@Champion
# 18:34:10  [INFO]  Prediction: LOW RISK (score=0.0096)
# {'risk_score': 0.0096, 'prediction': 0, 'risk_label': 'LOW RISK'}
